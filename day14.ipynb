# %%
#List down all the error types and check all the errors using a python program for all errors
 
#type error
s='sneha'
s+=1
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-23-16876d7c39dc> in <module>()
#       3 #type error
#       4 s='sneha'
# ----> 5 s+=1
#
# TypeError: can only concatenate str (not "int") to str

# %%
#syntax error 
myfunction(x, y):
    return x + y
else:
    print("Hello!")
if mark >= 50
    print("You passed!")
if arriving:
    print("Hi!")
esle:
    print("Bye!")
if flag:
print("Flag is set!")
# Out:
#   File "<ipython-input-4-8c320f983dcb>", line 1
#     myfunction(x, y):
#                      ^
# SyntaxError: invalid syntax

# %%
#zero division error
a=10
b=a/0
print(b)
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-6-b095f79a92f7> in <module>()
#       1 #zero division error
#       2 a=10
# ----> 3 b=a/0
#       4 print(b)
#
# ZeroDivisionError: division by zero

# %%
 #index error
letters = ["A","B"]
print(letters[2])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-10-2af62e16e3fc> in <module>()
#       1 #index error
#       2 letters = ["A", "B"]
# ----> 3 print(letters[2])
#
# IndexError: list index out of range

# %%
#name error
a=("apple","banana")
print(a1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-723eb56370d3> in <module>()
#       1 #name error
#       2 a=("apple","banana")
# ----> 3 print(a1)
#
# NameError: name 'a1' is not defined

# %%
#key error
dict={0:10,11:12,13:14}
print(dict[22])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-24-09673abf4a89> in <module>()
#       1 #key error
#       2 dict={0:10,11:12,13:14}
# ----> 3 print(dict[22])
#
# KeyError: 22

# %%
#value error
a="ab"
print(float(a))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-25-0ae516f8fc6d> in <module>()
#       1 #value error
#       2 a="ab"
# ----> 3 print(float(a))
#
# ValueError: could not convert string to float: 'ab'

# %%
#import error
from math import x
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-26-3db86a9a0ae4> in <module>()
#       1 #import error
# ----> 2 from math import x
#
# ImportError: cannot import name 'x' from 'math' (unknown location)
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
#module not found error
import mymodule1
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-27-2ddcdb6192c2> in <module>()
#       1 #module not found error
# ----> 2 import mymodule1
#
# ModuleNotFoundError: No module named 'mymodule1'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------
